# %% [markdown]
# ## **How to structure and document your project**

# %% [markdown]
# ### **Agenda**

# %% [markdown]
# - Project Repository Structure
# - Code Organization & Documentation
# - How to write a readme
# - Github Portfolio
# - Manage Version Control with Git
# - Q&A

# %% [markdown]
# ### **Project Repository Structure**

# %% [markdown]
# Data Projects usually follow this folders structure:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Code Organization and Documentation**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **How to write a readme file**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **4. Github Portfolio**

# %% [markdown]
# Github is a platform where you can create your project repository.
#
# Go to: https://github.com/

# %% [markdown]
# Sign up for github (in green)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Fill the information required.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Sign in and click on Create repository (in green).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Provide a repository name, click on Add README file, click on Create repository (in green)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Now you will see your project created in your profile. At this moment your project is empty.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Now we will clone the project into the local machine.

# %% [markdown]
# Click on code (in green) and copy the project url.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Create a folder called MasterSchool in your Desktop. Click the right button on it and copy the path of the folder.

# %% [markdown]
# - Windows: Open Command Prompt and write cd + the path in quotes.
#
# - Mac: mkdir ~/Desktop/my_data_project

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Install git in your pc.**

# %% [markdown]
# - Windows: winget install --id Git.Git -e --source winget
# - Mac: brew install git

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Now clone the repository:
#
#
# - Windows: git clone + the web url from your project.
#
# - Mac: git clone <repository-url>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Now you can check in your computer that the project you created in github is inside the MasterSchool folder in your pc (same for Mac users).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Create the project repository structure inside your my_data_project folder (same for Mac users).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# You can also put csv and other files in the folders.

# %% [markdown]
# For example here we put customers.csv into the data folder:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **update the web repository with the changes you have done in your local computer**
# - Windows:
#   - change directory into my_data_project (cd + path to my_data_project)
#   - git add * (update the web repository with the changes you have done in your local computer)
#
# - Mac:
#   - cd ~/Desktop/my_data_project
#   - git add *

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Check the status of your changes
# - Changes to be commited means you have added files but this are not commited to the remote repository yet.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Now let's commit the changes**
# Because this is your first time you will need to set your user name an mail before commiting
#
# - Windows:
#   - then you write and run: git commit -m "first upload"
#   - then you write and run: git push
#
# - Mac:
#   - git commit -m "Your commit message here"
#   - git push origin main

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# You will get this pop up. Click on the red square.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Click on the green square.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Now imagine someone changes de readme file from the remote repository(not your local machine).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# If we want to update the README file in your local machine, then we have to write:

# %% [markdown]
# - Windows:
#   - git pull
#
# - Mac:
#   - cd ~/Desktop/my_data_project
#   - git pull origin main

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Now you can see the changes in the file in the remote repository are now in your local machine.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
